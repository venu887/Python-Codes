# %%
print("hello venu")
# Out:
# hello venu

# %%
##Import CSV files or datasets
# import library called Pandas
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("J:\\Venu personal\Venu_py_Linux\\OVCCLE_R.csv")

# %%
df.head()
# Out:
#              Gene ID Description  A2780_OVARY  CAOV3_OVARY  COV318_OVARY  \
# 0  ENSG00000223972.4     DDX11L1      0.03490       0.0608        0.0958
# 1  ENSG00000227232.4      WASH7P     10.10000       2.9400        3.7000
# 2  ENSG00000243485.2  MIR1302-11      0.02910       0.0270        0.0745
# 3  ENSG00000237613.2     FAM138A      0.01220       0.0341        0.0603
# 4  ENSG00000268020.2      OR4G4P      0.00787       0.0329        0.0173
#
#    COV362_OVARY  COV434_OVARY  COV644_OVARY  ES2_OVARY  FUOV1_OVARY  ...  \
# 0       0.08880        0.0254        0.1880     0.0282      0.04190  ...
# 1       2.10000        4.7600        5.2800     3.1000      3.09000  ...
# 2       0.03590        0.0375        0.2390     0.0447      0.02330  ...
# 3       0.00565        0.0177        0.1630     0.0169      0.02200  ...
# 4       0.00000        0.0228        0.0968     0.0145      0.00944  ...
#
#    KURAMOCHI_OVARY  NIHOVCAR3_OVARY  OAW42_OVARY  OC314_OVARY  ONCODG1_OVARY  \
# ...

# %%
df.tail()
# Out:
#                  Gene ID Description  A2780_OVARY  CAOV3_OVARY  COV318_OVARY  \
# 56197  ENSG00000198695.2      MT-ND6     2790.000     2780.000      11900.00
# 56198  ENSG00000210194.1       MT-TE        2.480        4.810         13.90
# 56199  ENSG00000198727.2      MT-CYB     3850.000     3430.000      12500.00
# 56200  ENSG00000210195.2       MT-TT        0.677        0.472          2.97
# 56201  ENSG00000210196.2       MT-TP        0.438        0.458          4.09
#
#        COV362_OVARY  COV434_OVARY  COV644_OVARY  ES2_OVARY  FUOV1_OVARY  ...  \
# 56197      3040.000      3080.000      3950.000   1180.000     3440.000  ...
# 56198         3.290         5.010         3.100      1.890        2.980  ...
# 56199      2330.000      3000.000      4060.000   2800.000     3660.000  ...
# 56200         0.209         0.328         0.232      0.312        0.135  ...
# 56201         0.607         1.060         2.250      0.505        1.180  ...
#
# ...

# %%
df.shape
# Out:
# (56202, 48)

# %%
df.columns
# Out:
# Index(['Gene ID', 'Description', 'A2780_OVARY', 'CAOV3_OVARY', 'COV318_OVARY',
#        'COV362_OVARY', 'COV434_OVARY', 'COV644_OVARY', 'ES2_OVARY',
#        'FUOV1_OVARY', 'IGROV1_OVARY', 'JHOC5_OVARY', 'JHOM1_OVARY',
#        'JHOM2B_OVARY', 'JHOS2_OVARY', 'JHOS4_OVARY', 'MCAS_OVARY',
#        'OAW28_OVARY', 'OV56_OVARY', 'OV7_OVARY', 'OVCAR4_OVARY',
#        'OVCAR8_OVARY', 'OVK18_OVARY', 'OVKATE_OVARY', 'OVMANA_OVARY',
#        'RMGI_OVARY', 'RMUGS_OVARY', 'SNU119_OVARY', 'SNU840_OVARY',
#        'SNU8_OVARY', 'TOV112D_OVARY', 'TOV21G_OVARY', 'TYKNU_OVARY',
#        '59M_OVARY', 'CAOV4_OVARY', 'EFO21_OVARY', 'EFO27_OVARY', 'HEYA8_OVARY',
#        'KURAMOCHI_OVARY', 'NIHOVCAR3_OVARY', 'OAW42_OVARY', 'OC314_OVARY',
#        'ONCODG1_OVARY', 'OV90_OVARY', 'OVISE_OVARY', 'OVSAHO_OVARY',
#        'OVTOKO_OVARY', 'SKOV3_OVARY'],
#       dtype='object')

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.dtypes
# Out:
# Gene ID             object
# Description         object
# A2780_OVARY        float64
# CAOV3_OVARY        float64
# COV318_OVARY       float64
# COV362_OVARY       float64
# COV434_OVARY       float64
# COV644_OVARY       float64
# ES2_OVARY          float64
# FUOV1_OVARY        float64
# IGROV1_OVARY       float64
# JHOC5_OVARY        float64
# JHOM1_OVARY        float64
# JHOM2B_OVARY       float64
# JHOS2_OVARY        float64
# JHOS4_OVARY        float64
# MCAS_OVARY         float64
# OAW28_OVARY        float64
# OV56_OVARY         float64
# OV7_OVARY          float64
# OVCAR4_OVARY       float64
# OVCAR8_OVARY       float64
# OVK18_OVARY        float64
# OVKATE_OVARY       float64
# OVMANA_OVARY       float64
# RMGI_OVARY         float64
# RMUGS_OVARY        float64
# SNU119_OVARY       float64
# SNU840_OVARY       float64
# SNU8_OVARY         float64
# TOV112D_OVARY      float64
# TOV21G_OVARY       float64
# TYKNU_OVARY        float64
# 59M_OVARY          float64
# ...

# %%
df2.head()
# Out:
#                                     CCLE_ID    depMapID       Name  \
# 0                                DMS53_LUNG  ACH-000698     DMS 53
# 1                    SW1116_LARGE_INTESTINE  ACH-000489     SW1116
# 2                             NCIH1694_LUNG  ACH-000431  NCI-H1694
# 3  P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ACH-000707     P3HR-1
# 4  HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ACH-000509     HuT 78
#
#     Pathology                        Site_Primary Site_Subtype1 Site_Subtype2  \
# 0     primary                                lung            NS            NS
# 1     primary                     large_intestine         colon            NS
# 2  metastasis                                lung            NS            NS
# 3  metastasis  haematopoietic_and_lymphoid_tissue            NS            NS
# 4     primary  haematopoietic_and_lymphoid_tissue          skin            NS
#
#   Site_Subtype3          Histology                      Hist_Subtype1  ...  \
# ...

# %%
df.tail(3)
# Out:
#                  Gene ID Description  A2780_OVARY  CAOV3_OVARY  COV318_OVARY  \
# 56199  ENSG00000198727.2      MT-CYB     3850.000     3430.000      12500.00
# 56200  ENSG00000210195.2       MT-TT        0.677        0.472          2.97
# 56201  ENSG00000210196.2       MT-TP        0.438        0.458          4.09
#
#        COV362_OVARY  COV434_OVARY  COV644_OVARY  ES2_OVARY  FUOV1_OVARY  ...  \
# 56199      2330.000      3000.000      4060.000   2800.000     3660.000  ...
# 56200         0.209         0.328         0.232      0.312        0.135  ...
# 56201         0.607         1.060         2.250      0.505        1.180  ...
#
#        KURAMOCHI_OVARY  NIHOVCAR3_OVARY  OAW42_OVARY  OC314_OVARY  \
# 56199         7170.000         3350.000     3000.000     5280.000
# 56200            0.873            0.617        0.494        0.625
# 56201            2.400            0.299        1.340        1.700
#
#        ONCODG1_OVARY  OV90_OVARY  OVISE_OVARY  OVSAHO_OVARY  OVTOKO_OVARY  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=56202, step=1)

# %%
df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of                  Gene ID Description  A2780_OVARY  CAOV3_OVARY  COV318_OVARY  \
# 0      ENSG00000223972.4     DDX11L1      0.03490       0.0608        0.0958
# 1      ENSG00000227232.4      WASH7P     10.10000       2.9400        3.7000
# 2      ENSG00000243485.2  MIR1302-11      0.02910       0.0270        0.0745
# 3      ENSG00000237613.2     FAM138A      0.01220       0.0341        0.0603
# 4      ENSG00000268020.2      OR4G4P      0.00787       0.0329        0.0173
# ...                  ...         ...          ...          ...           ...
# 56197  ENSG00000198695.2      MT-ND6   2790.00000    2780.0000    11900.0000
# 56198  ENSG00000210194.1       MT-TE      2.48000       4.8100       13.9000
# 56199  ENSG00000198727.2      MT-CYB   3850.00000    3430.0000    12500.0000
# 56200  ENSG00000210195.2       MT-TT      0.67700       0.4720        2.9700
# 56201  ENSG00000210196.2       MT-TP      0.43800       0.4580        4.0900
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                  Gene ID Description  A2780_OVARY  CAOV3_OVARY  COV318_OVARY  \
# 0      ENSG00000223972.4     DDX11L1      0.03490       0.0608        0.0958
# 1      ENSG00000227232.4      WASH7P     10.10000       2.9400        3.7000
# 2      ENSG00000243485.2  MIR1302-11      0.02910       0.0270        0.0745
# 3      ENSG00000237613.2     FAM138A      0.01220       0.0341        0.0603
# 4      ENSG00000268020.2      OR4G4P      0.00787       0.0329        0.0173
# ...                  ...         ...          ...          ...           ...
# 56197  ENSG00000198695.2      MT-ND6   2790.00000    2780.0000    11900.0000
# 56198  ENSG00000210194.1       MT-TE      2.48000       4.8100       13.9000
# 56199  ENSG00000198727.2      MT-CYB   3850.00000    3430.0000    12500.0000
# 56200  ENSG00000210195.2       MT-TT      0.67700       0.4720        2.9700
# 56201  ENSG00000210196.2       MT-TP      0.43800       0.4580        4.0900
#
# ...

# %%
# Transposing data:
df.T
# Out:
#                              0                  1                  2      \
# Gene ID          ENSG00000223972.4  ENSG00000227232.4  ENSG00000243485.2
# Description                DDX11L1             WASH7P         MIR1302-11
# A2780_OVARY                 0.0349               10.1             0.0291
# CAOV3_OVARY                 0.0608               2.94              0.027
# COV318_OVARY                0.0958                3.7             0.0745
# COV362_OVARY                0.0888                2.1             0.0359
# COV434_OVARY                0.0254               4.76             0.0375
# COV644_OVARY                 0.188               5.28              0.239
# ES2_OVARY                   0.0282                3.1             0.0447
# FUOV1_OVARY                 0.0419               3.09             0.0233
# IGROV1_OVARY                0.0219               3.32             0.0607
# JHOC5_OVARY                 0.0323               4.58             0.0359
# ...

# %%
#Sorting by an axis:
df.sort_index(axis=1, ascending=False)
# Out:
#        TYKNU_OVARY  TOV21G_OVARY  TOV112D_OVARY  SNU8_OVARY  SNU840_OVARY  \
# 0           0.0080        0.0216         0.0221      0.0733       0.00948
# 1           4.8700        4.7200         5.0000      3.7200       2.72000
# 2           0.0355        0.0120         0.0393      0.0465       0.02110
# 3           0.0392        0.0000         0.0186      0.0439       0.02650
# 4           0.0144        0.0000         0.0239      0.0314       0.03420
# ...            ...           ...            ...         ...           ...
# 56197    2390.0000     2470.0000      3380.0000   4050.0000    2880.00000
# 56198       3.5600        2.0000         5.3600      5.0900       4.10000
# 56199    4590.0000     2970.0000      4510.0000   6960.0000    3390.00000
# 56200       0.3100        0.1400         0.3430      0.2710       1.59000
# 56201       1.1000        0.9480         1.2200      2.1900       2.02000
#
#        SNU119_OVARY  SKOV3_OVARY  RMUGS_OVARY  RMGI_OVARY  OVTOKO_OVARY  ...  \
# ...

# %%
Sorting by values:

df.sort_values(by="TYKNU_OVARY")
# Out:
#   Input In [38]
#     Sorting by values:
#             ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df .columns
#
# NameError: name 'df' is not defined
